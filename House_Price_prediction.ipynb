# %%
#Task 1: Importing the data
#--- Import Pandas ---
import pandas as pd
#--- Read in dataset ----
file_path= r'C:\Users\003UWG744\Downloads\HousePricePrediction.csv'
df = pd.read_csv(file_path)

#--- Inspect data ---
df
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# ...

# %% [raw]
# Task 2: Unveiling Missing Data
# By calculating the count of missing values for each column, named "sumofnull," we gain a clear map of where data gaps reside. This insight serves as a compass, guiding us to areas of data cleansing and preparation, ensuring the integrity and accuracy of our data-driven discoveries.

# %%
# --- WRITE YOUR CODE FOR MODULE 2 TASK 1 ---
sumofnull = df.isnull().sum()
#--- Inspect data ---
print(sumofnull)
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotArea            0
# LotConfig          0
# BldgType           0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# Exterior1st        1
# BsmtFinSF2         1
# TotalBsmtSF        1
# SalePrice       1459
# dtype: int64

# %% [raw]
# Task 3: Imputing Missing Values
# Utilizing Python and Pandas, we impute missing values within our dataset, focusing on the 'SalePrice' column. By replacing these gaps with the column's mean value, we ensure the dataset's completeness. This transformation equips us with a more robust dataset for further analysis and modeling, enhancing the accuracy of our insights.

# %%
# --- WRITE YOUR CODE FOR MODULE 2 TASK 2 ---
Smean=df['SalePrice'].mean()
#df = ...
df['SalePrice'].fillna(Smean,inplace=True)

# %% [raw]
# Task 4: Handling Rows with Missing Values
# In our journey toward pristine data, we utilize Python and Pandas to refine our dataset. With precision, we remove rows containing missing values using the dropna() function. This meticulous process ensures that our dataset is free from incomplete data points, offering a clean slate for analysis and modeling, ultimately enhancing the quality of our insights.

# %%
df1 = df.dropna()
df1
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  \
# ...

# %% [raw]
# Task 5: Feature Selection
# In our pursuit of data efficiency, we execute a strategic move. Armed with Python and Pandas, we remove the 'Id' column from our dataset using the drop() function. This selective action streamlines our data, eliminating an unnecessary feature and preparing it for further analysis and modeling, enhancing the precision of our insights.

# %%
data=df1.drop(columns='Id')
data
# Out:
#       MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  YearBuilt  \
# 0             60       RL     8450    Inside     1Fam            5       2003
# 1             20       RL     9600       FR2     1Fam            8       1976
# 2             60       RL    11250    Inside     1Fam            5       2001
# 3             70       RL     9550    Corner     1Fam            5       1915
# 4             60       RL    14260       FR2     1Fam            5       2000
# ...          ...      ...      ...       ...      ...          ...        ...
# 2914         160       RM     1936    Inside    Twnhs            7       1970
# 2915         160       RM     1894    Inside   TwnhsE            5       1970
# 2916          20       RL    20000    Inside     1Fam            7       1960
# 2917          85       RL    10441    Inside     1Fam            5       1992
# 2918          60       RL     9627    Inside     1Fam            5       1993
#
# ...

# %% [raw]
# Task 6: Exploring Feature Correlations
# In our exploration of data relationships, we dive deep into the world of feature correlations. With Python, Pandas, Matplotlib, and Seaborn by our side, we calculate and visualize the correlation matrix for our numerical columns. The resulting heatmap, adorned with annotations, provides a clear and visual representation of how these features interrelate. This graphical insight equips us to better understand the data dynamics and informs our subsequent data-driven decisions.

# %%
#--- Import matplotlib and  seaborn---
import matplotlib.pyplot as plt
import seaborn as sns
corr = data.select_dtypes(include='number').corr()
print(corr)
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(corr, ax=ax, annot=True, square=True, cmap='coolwarm', fmt='.2f')
ax.set_title('Correlation Matrix Heatmap', pad=20)
plt.show()
# Out:
#               MSSubClass   LotArea  OverallCond  YearBuilt  YearRemodAdd  \
# MSSubClass      1.000000 -0.202661    -0.066033   0.033428      0.042057
# LotArea        -0.202661  1.000000    -0.025024   0.031226      0.027047
# OverallCond    -0.066033 -0.025024     1.000000  -0.375150      0.043586
# YearBuilt       0.033428  0.031226    -0.375150   1.000000      0.611755
# YearRemodAdd    0.042057  0.027047     0.043586   0.611755      1.000000
# BsmtFinSF2     -0.072839  0.085927     0.040980  -0.028329     -0.062818
# TotalBsmtSF    -0.222397  0.262102    -0.180554   0.407691      0.294832
# SalePrice      -0.059326  0.237990    -0.055299   0.369442      0.355167
#
#               BsmtFinSF2  TotalBsmtSF  SalePrice
# MSSubClass     -0.072839    -0.222397  -0.059326
# LotArea         0.085927     0.262102   0.237990
# OverallCond     0.040980    -0.180554  -0.055299
# YearBuilt      -0.028329     0.407691   0.369442
# YearRemodAdd   -0.062818     0.294832   0.355167
# ...

# %% [raw]
# Task 7: Exploring Categorical Features
# In our quest to unveil the essence of categorical data, we embark on a visual adventure. Armed with Python, Pandas, Matplotlib, and Seaborn, we set the stage to explore the distribution of categorical features. Our canvas, divided into an array of subplots, reveals the frequency distribution of each category within these features. As we scrutinize this visual landscape, insights emerge, offering a deeper understanding of our data's categorical dynamics. The counts of each category, meticulously recorded, stand as a testament to our journey's discoveries.

# %%
# --- WRITE YOUR CODE TASK 2 ---
cat_cols = ['MSZoning','LotConfig','BldgType','Exterior1st']
num_cols =['LotArea','TotalBsmtSF','MSSubClass','YearRemodAdd','BsmtFinSF2','YearBuilt','OverallCond','SalePrice']
counts={}
index=1
fig, axes = plt.subplots(len(cat_cols), 1, figsize=(12, 12))
for col in cat_cols:
    counts[col]=data[col].value_counts().to_dict()
    ax=axes[index-1]
    ct_sr=pd.Series(counts[col])
    ct_sr.plot(kind='bar',ax=ax)
    ax.set_title(col)
    ax.set_xlabel(col)
    ax.set_ylabel('Count')
    ax.tick_params(axis='x',rotation=90)
    index+=1
plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %% [raw]
# Task 8: Encoding Categorical Features
# With precision, we utilize the get_dummies() function to transform these features into a structured, numerical format. Each unique category is meticulously encoded, with prefix separation denoting their origins. The result—df_encoded—is a transformed dataset, primed for advanced analysis and modeling, where the hidden insights within categorical data can be fully harnessed.

# %%
df_encoded=pd.get_dummies(data,columns=cat_cols,prefix_sep='_')
print(df_encoded)
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 0             60     8450            5       2003          2003         0.0
# 1             20     9600            8       1976          1976         0.0
# 2             60    11250            5       2001          2002         0.0
# 3             70     9550            5       1915          1970         0.0
# 4             60    14260            5       2000          2000         0.0
# ...          ...      ...          ...        ...           ...         ...
# 2914         160     1936            7       1970          1970         0.0
# 2915         160     1894            5       1970          1970         0.0
# 2916          20    20000            7       1960          1996         0.0
# 2917          85    10441            5       1992          1992         0.0
# 2918          60     9627            5       1993          1994         0.0
#
# ...

# %% [raw]
# Task 9: Data Splitting
# Leveraging the power of Scikit-Learn, we partition our encoded dataset into two essential components: X and Y. X encompasses the feature matrix, excluding the 'SalePrice' column, while Y represents the target variable 'SalePrice' itself.
#
# The division is carefully orchestrated, with 80% of the data allocated for training (X_train, Y_train) and 20% for validation (X_valid, Y_valid). This strategic partitioning, executed with precision, forms the blueprint for our data analysis and modeling endeavors, paving the way for predictive insights and model evaluation.

# %%
#--- Import train_test_split from sklearn.model_selection ---
from sklearn.model_selection import train_test_split
# --- WRITE YOUR CODE FOR MODULE 4 TASK 2 ---
Y=df_encoded['SalePrice']
X=df_encoded.drop(columns=['SalePrice'])
X_train,X_valid,Y_train,Y_valid=train_test_split(X,Y,test_size=0.2,random_state=0)
#X_train,X_valid,Y_train, Y_valid = ...
#print(Y_train)

# %% [raw]
# Task 10: Model Building and Evaluation
#  machine learning models, including Linear Regression, Random Forest Regression, Support Vector Regression (SVR), and Ridge Regression. These models, trained on the training dataset, predict housing prices on the validation set. We assess their predictive accuracy using Mean Absolute Percentage Error (MAPE). This rigorous evaluation guides us in selecting the best model for housing price prediction, enhancing data-driven real estate decisions.

# %%
#--- Import LinearRegression,RandomForestRegressor,svm,Ridge, mean_absolute_percentage_error,from sklearn ---
from sklearn.linear_model import LinearRegression,Ridge 
from sklearn.ensemble import RandomForestRegressor  
from sklearn.svm import SVR 
from sklearn.metrics import mean_absolute_percentage_error
#Intilize and fit Linear Regression model and find mape for lr model
model_LR=LinearRegression()
model_LR.fit(X_train,Y_train)
Y_pred=model_LR.predict(X_valid)
lr_mape = mean_absolute_percentage_error(Y_valid,Y_pred)
print(lr_mape)
#Intilize  and fit Random Forest model and find mape for rf model
model_RF=RandomForestRegressor()
model_RF.fit(X_train,Y_train)
Y_pred1=model_RF.predict(X_valid)
rf_mape = mean_absolute_percentage_error(Y_valid,Y_pred1)
print(rf_mape)

#Intilize  and fit svm model and find mape for svr model
#X_train2.replace({False:0,True:1},inplace=True)
model_SVR=SVR()
model_SVR.fit(X_train, Y_train)
Y_pred2=model_SVR.predict(X_valid)
svr_mape =mean_absolute_percentage_error(Y_valid,Y_pred2)
print(svr_mape)

#Intilize  and fit Ridge Regression model and find mape for ridge model
model_ridge=Ridge()
model_ridge.fit(X_train,Y_train)
Y_pred3=model_ridge.predict(X_valid)
ridge_mape =mean_absolute_percentage_error(Y_valid,Y_pred3)
print(ridge_mape)
# Out:
# 0.1874168384159986
# 0.18647238850919687
# 0.1870512931870423
# 0.18720223297663927

# %% [raw]
# Task 11: Model Performance Evaluation
#  The SVR model, trained on the dataset, predicts housing prices on the validation set. Key metrics, including R-squared (r2), Mean Absolute Error (MAE), and Root Mean Squared Error (RMSE), quantify its accuracy. These insights guide us in enhancing the model's predictive capabilities for precise real estate predictions.

# %%
#--- Import  r2_score, mean_squared_error, mean_absolute_error from sklearn.metrics ---
#Choose the best model from previous task and find its other metrics
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
r2 = r2_score(Y_valid,Y_pred2)  # Calculate R-squared score
mae = mean_absolute_error(Y_valid,Y_pred2)  # Calculate Mean Absolute Error
rmse = mean_squared_error(Y_valid,Y_pred2,squared=False) # Calculate rmse
print(r2 ,'\n',mae, '\n', rmse )
# Out:
# 1.6224524168606536e-06
#  28848.681203988202
#  52000.90213813493
